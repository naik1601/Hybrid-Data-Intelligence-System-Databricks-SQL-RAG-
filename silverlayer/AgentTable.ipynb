# %%
# %sql
CREATE OR REPLACE TABLE policyprojcatalog.silver.Agent (
  agent_id INT,
  agent_name STRING,
  agent_email STRING,
  agent_phone STRING,
  branch_id INT,
  create_timestamp TIMESTAMP,
  merged_timestamp TIMESTAMP
)
USING DELTA
LOCATION 'abfss://silverlayer@projpolicysytem.dfs.core.windows.net/Agent';
