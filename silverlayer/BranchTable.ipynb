# %%
# %sql
CREATE OR REPLACE TABLE policyprojcatalog.silver.Branch (
  branch_id INT,
  branch_country STRING,
  branch_city STRING,
  merged_timestamp TIMESTAMP
)
USING DELTA
LOCATION 'abfss://silverlayer@projpolicysytem.dfs.core.windows.net/Branch';
