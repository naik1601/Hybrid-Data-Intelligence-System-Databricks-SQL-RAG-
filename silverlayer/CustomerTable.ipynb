# %%
# %sql
CREATE OR REPLACE TABLE policyprojcatalog.silver.Customer (
  customer_id INT,
  first_name STRING,
  last_name STRING,
  email STRING,
  phone STRING,
  country STRING,
  city STRING,
  registration_date TIMESTAMP,
  date_of_birth TIMESTAMP,
  gender STRING,
  merged_timestamp TIMESTAMP
)
USING DELTA
LOCATION 'abfss://silverlayer@projpolicysytem.dfs.core.windows.net/Customer';
