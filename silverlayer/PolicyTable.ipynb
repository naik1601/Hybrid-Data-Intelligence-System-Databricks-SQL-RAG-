# %%
# %sql
CREATE OR REPLACE TABLE policyprojcatalog.silver.Policy (
  policy_id INT,
  policy_type STRING,
  customer_id INT,
  start_date TIMESTAMP,
  end_date TIMESTAMP,
  premium DOUBLE,
  coverage_amount DOUBLE,
  merged_timestamp TIMESTAMP
)
USING DELTA
LOCATION 'abfss://silverlayer@projpolicysytem.dfs.core.windows.net/Policy';
