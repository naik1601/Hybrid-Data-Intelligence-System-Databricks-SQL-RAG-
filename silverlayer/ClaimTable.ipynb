# %%
# %sql
CREATE OR REPLACE TABLE policyprojcatalog.silver.Claim (
  claim_id INT,
  policy_id INT,
  date_of_claim DATE,
  claim_amount DECIMAL(18,0),
  claim_status STRING,
  LastUpdatedTimeStamp TIMESTAMP,
  merged_timestamp TIMESTAMP
)
USING DELTA
LOCATION 'abfss://silverlayer@projpolicysytem.dfs.core.windows.net/Claim';
